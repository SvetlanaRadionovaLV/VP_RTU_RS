# %% [markdown]
# <a href="https://colab.research.google.com/gist/SvetlanaRadionovaLV/371a114f0e650ca7b5e7e3f7ca49bc42/comands_okama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import okama as ok

# %%
a_list = ok.AssetList(['SPY.US','AGG.US', 'T.US'])

# %%
a_list.wealth_indexes
# Out:
#               SPY.US       AGG.US         T.US     USD.INFL
# date
# 2003-10  1000.000000  1000.000000  1000.000000  1000.000000
# 2003-11  1064.983150   993.969310  1070.015760   996.202970
# 2003-12  1118.551802  1003.710209  1198.203648   995.107147
# 2004-01  1140.699128  1008.126534  1190.175684   999.983172
# 2004-02  1156.212636  1019.619177  1120.669424  1005.383081
# ...              ...          ...          ...          ...
# 2022-08  5690.880063  1769.628215  4157.940522  1599.220463
# 2022-09  5165.042745  1696.365607  3636.534781  1602.738748
# 2022-10  5584.960721  1674.652127  4398.388817  1609.309977
# 2022-11  5895.484537  1738.456373  4651.736013  1607.700667
# 2022-12  5555.904627  1727.330252  4441.942719  1602.716795
#
# [231 rows x 4 columns]

# %%
a_list.wealth_indexes.plot()
# Out:
# <AxesSubplot: xlabel='date'>

# %%
a_list.describe()
# Out:
#                  property              period    SPY.US    AGG.US      T.US  \
# 0         Compound return                 YTD -0.181622 -0.128159  0.064887
# 1                    CAGR             1 years -0.181622 -0.128159  0.064887
# 2                    CAGR             5 years  0.093189  0.000346 -0.010754
# 3                    CAGR            10 years  0.124612  0.010389  0.043907
# 4                    CAGR  19 years, 3 months  0.093172  0.028801  0.080538
# 5          Dividend yield                 LTM  0.016528  0.021574  0.073547
# 6                    Risk  19 years, 3 months  0.163617  0.042415  0.204859
# 7                    CVAR  19 years, 3 months  0.399398  0.142776  0.319974
# 8           Max drawdowns  19 years, 3 months -0.507799  -0.17133 -0.382621
# 9     Max drawdowns dates  19 years, 3 months   2009-02   2022-10   2009-02
# 10         Inception date                None   1993-02   2003-10   1984-12
# 11        Last asset date                None   2023-01   2023-01   2023-01
# 12  Common last data date                None   2022-12   2022-12   2022-12
#
#    inflation
# 0   0.064548
# 1   0.064548
# 2   0.037869
# 3   0.026028
# 4   0.024807
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10   2003-10
# 11   2022-12
# 12   2022-12

# %% [markdown]
# YTD - Year To Date

# %%
a_list.drawdowns.plot()
# Out:
# <AxesSubplot: xlabel='date'>

# %%
a_list.assets_dividend_yield.plot()
# Out:
# <AxesSubplot: >

# %%
ok.search('index')
# Out:
#            symbol  ticker                                               name  \
# 0     990100.INDX  990100               MSCI International World Index Price
# 1       ACWI.INDX    ACWI               MSCI International ACWI Net Index US
# 2        AEX.INDX     AEX                                AEX Amsterdam Index
# 3        ASX.INDX     ASX                               FTSE All Share Index
# 4        ATX.INDX     ATX                       Austrian Traded Index in EUR
# ...           ...     ...                                                ...
# 2308     WFIOX.US   WFIOX                     INDEX FUND ADMINISTRATOR CLASS
# 2309     WFIVX.US   WFIVX          WILSHIRE 5000 INDEX FUND INVESTMENT CLASS
# 2310     WFSPX.US   WFSPX        BLACKROCK S&P 500 INDEX FUND CLASS K SHARES
# 2311     WINDX.US   WINDX       WILSHIRE 5000 INDEX FUND INSTITUTIONAL CLASS
# 2312      ZROZ.US    ZROZ  PIMCO 25+ Year Zero Coupon U.S. Treasury Index...
#
#           country   exchange currency   type          isin
# 0         Unknown       INDX      USD  INDEX
# 1             USA       INDX      USD  INDEX
# 2     Netherlands       INDX      EUR  INDEX
# 3              UK       INDX      GBP  INDEX
# 4         Austria       INDX      EUR  INDEX
# ...           ...        ...      ...    ...           ...
# 2308          USA      NMFQS      USD   FUND  US94975G6860
# 2309          USA      NMFQS      USD   FUND  US9718978557
# 2310          USA      NMFQS      USD   FUND  US0669222046
# 2311          USA      NMFQS      USD   FUND
# 2312          USA  NYSE ARCA      USD    ETF  US72201R8824
#
# [2313 rows x 8 columns]

# %%
b_list = ok.AssetList(['AEX.INDX','AMX.INDX','BEL20.INDX'], ccy = "RUB")

# %%
b_list.wealth_indexes.plot()
# Out:
# <AxesSubplot: xlabel='date'>

# %%
b_list = ok.AssetList(['AEX.INDX','AMX.INDX','BEL20.INDX'], ccy = "RUB")

# %%
b_list.tracking_difference().plot()
# Out:
# <AxesSubplot: xlabel='date'>

# %%
b_list.tracking_difference_annualized().plot()
# Out:
# <AxesSubplot: xlabel='date'>

# %%
vesa = [0.2, 0.4, 0.1, 0.3]
index = ['AEX.INDX','AMX.INDX','BEL20.INDX','CEX.INDX']

# %%
c_prtf = ok.Portfolio(index, ccy = "EUR", weights = vesa, first_date='2003-01')

# %%
c_prtf
# Out:
# symbol                                         portfolio_8438.PF
# assets                [AEX.INDX, AMX.INDX, BEL20.INDX, CEX.INDX]
# weights                                     [0.2, 0.4, 0.1, 0.3]
# rebalancing_period                                         month
# currency                                                     EUR
# inflation                                               EUR.INFL
# first_date                                               2003-01
# last_date                                                2022-12
# period_length                                 20 years, 0 months
# dtype: object

# %%
c_prtf.table
# Out:
#             asset name      ticker  weights
# 0  AEX Amsterdam Index    AEX.INDX      0.2
# 1                  AMX    AMX.INDX      0.4
# 2         BEL-20 INDEX  BEL20.INDX      0.1
# 3      Chemicals Index    CEX.INDX      0.3

# %%
c_prtf.wealth_index.plot()
# Out:
# <AxesSubplot: xlabel='date'>

# %%
c_prtf.wealth_index_with_assets.plot()
# Out:
# <AxesSubplot: xlabel='date'>

# %%
c_prtf.describe
# Out:
# <bound method Portfolio.describe of symbol                                         portfolio_8438.PF
# assets                [AEX.INDX, AMX.INDX, BEL20.INDX, CEX.INDX]
# weights                                     [0.2, 0.4, 0.1, 0.3]
# rebalancing_period                                         month
# currency                                                     EUR
# inflation                                               EUR.INFL
# first_date                                               2003-01
# last_date                                                2022-12
# period_length                                 20 years, 0 months
# dtype: object>

# %%
c_prtf.plot_forecast(years=5, percentiles=[1,10,50,90,99])
# Out:
# <AxesSubplot: >

# %%
c_prtf.plot_forecast_monte_carlo(years=2)

# %%
akc = ['SPY.US','AGG.US','GLD.US','RGBITR.INDX']

# %%
ok.EfficientFrontier(akc, ccy = 'EUR').plot_assets(kind = 'mean')
# Out:
# <AxesSubplot: >

# %%
import matplotlib.pyplot as plt

# %%
e_eff = ok.EfficientFrontier(akc, ccy = 'EUR', last_date='2022-12')

# %%
montcar = e_eff.get_monte_carlo(n=1000, kind='mean')

# %%
fig = plt.figure(figsize=(20,20))
e_eff.plot_assets(kind='cagr')
ax = plt.gca()

df = e_eff.ef_points
# ax.plot(df['Risk'], df['CAGR'], color='black', linestyle='solid', linewidth=2.0)
# fig.subplots_adjust(bottom=0.2, top=1.5)
ax.scatter(montcar.Risk, montcar.Return)
plt.show()

# %%
ef = e_eff.ef_points

# %%
fig = plt.figure(figsize=(10,10))
fig.subplots_adjust(bottom=0.2, top=1.5)

e_eff.plot_assets(kind='mean')
ax = plt.gca()
ax.plot(ef.Risk, ef['Mean return'], color='black', linestyle='solid', linewidth=2.0)

ax.scatter(montcar.Risk, montcar.Return)

# %%
fig = plt.figure(figsize=(10,10))
fig.subplots_adjust(bottom=0.2, top=1.5)

e_eff.plot_assets(kind='cagr')
ax = plt.gca()
ax.plot(ef.Risk, ef['CAGR'], color='black', linestyle='solid', linewidth=2.0)

# ax.scatter(montcar.Risk, montcar.Return)
